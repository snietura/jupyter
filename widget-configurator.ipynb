# %%
import ipywidgets as widgets
from IPython.display import display

# %%
widget_repo = {'Suwak liczb całkowitych': 
                    {'desc': 'Suwak do określania wartości całkowitej z wybranego zakresu',
                     'cons': 'IntSlider',
                     'cat' : 'numeric',
                     'props': {'value': 
                                    {'type': 'int',
                                     'desc': 'wybrana wartość suwaka',
                                     'def' : '0'
                                    },
                               'min': 
                                    {'type': 'int',
                                     'desc': 'wartość minimalna suwaka',
                                     'def' : '0'
                                    },
                               'max':
                                    {'type': 'int',
                                     'desc': 'wartość maksymalna suwaka',
                                     'def' : '100'
                                    },
                               'step': 
                                    {'type': 'int',
                                     'desc': 'skok suwaka',
                                     'def' : '1'
                                    },
                               'description': 
                                    {'type': 'string',
                                     'desc': 'opis/etykieta wyświetlany przy suwaku',
                                     'def' : ''
                                    },
                               'description_tooltip':
                                    {'type': 'string',
                                     'desc': 'opis wyświetlany przy najechaniu kursorem na suwak',
                                     'def' : ''
                                    },
                               'disabled': 
                                    {'type': 'bool',
                                     'desc': 'czy suwak jest wyłączony/nieaktywny',
                                     'def' : 'False'
                                    },
                               'continuous_update': 
                                    {'type': 'bool',
                                     'desc': 'czy wartość zmienia się podczas przeciągania myszą lub dopiero po puszczeniu',
                                     'def' : 'True'
                                    },
                               'orientation': 
                                    {'type': 'horizontal|vertical',
                                     'desc': 'orientracja pozioma lub pionowa',
                                     'def' : 'horizontal'
                                    },
                               'readout': 
                                    {'type': 'bool',
                                     'desc': 'czy wyświetlać aktualną wartość w postaci liczbowej',
                                     'def' : 'True'
                                    },
                               'readout_format': 
                                    {'type': 'string',
                                     'desc': 'string formatujący wartość liczbową',
                                     'def' : 'd'
                                    }
                              }
                    }, 
              'Suwak liczb rzeczywistych':
                    {'desc': 'Suwak do określania wartości całkowitej z wybranego zakresu',
                     'cons': 'IntSlider',
                     'cat' : 'numeric',
                     'props': {'value': 
                                    {'type': 'float',
                                     'desc': 'wybrana wartość suwaka',
                                     'def' : '0.0'
                                    },
                               'min': 
                                    {'type': 'float',
                                     'desc': 'wartość minimalna suwaka',
                                     'def' : '0.0'
                                    },
                               'max':
                                    {'type': 'float',
                                     'desc': 'wartość maksymalna suwaka',
                                     'def' : '100.0'
                                    },
                               'step': 
                                    {'type': 'float',
                                     'desc': 'skok suwaka',
                                     'def' : '0.1'
                                    },
                               'description': 
                                    {'type': 'string',
                                     'desc': 'opis/etykieta wyświetlany przy suwaku',
                                     'def' : ''
                                    },
                               'description_tooltip':
                                    {'type': 'string',
                                     'desc': 'opis wyświetlany przy najechaniu kursorem na suwak',
                                     'def' : ''
                                    },
                               'disabled': 
                                    {'type': 'bool',
                                     'desc': 'czy suwak jest wyłączony/nieaktywny',
                                     'def' : 'False'
                                    },
                               'continuous_update': 
                                    {'type': 'bool',
                                     'desc': 'czy wartość zmienia się podczas przeciągania myszą lub dopiero po puszczeniu',
                                     'def' : 'True'
                                    },
                               'orientation': 
                                    {'type': 'horizontal|vertical',
                                     'desc': 'orientracja pozioma lub pionowa',
                                     'def' : 'horizontal'
                                    },
                               'readout': 
                                    {'type': 'bool',
                                     'desc': 'czy wyświetlać aktualną wartość w postaci liczbowej',
                                     'def' : 'True'
                                    },
                               'readout_format': 
                                    {'type': 'string',
                                     'desc': 'string formatujący wartość liczbową',
                                     'def' : '.2f'
                                    }
                              }
                    },  
              'Suwak wykładniczy rzeczywistych':
                    {'desc': 'Suwak do określania wartości całkowitej z wybranego zakresu',
                     'cons': 'IntSlider',
                     'cat' : 'numeric',
                     'props': {'value': 
                                    {'type': 'float',
                                     'desc': 'wybrana wartość suwaka',
                                     'def' : '0.0'
                                    },
                               'base':
                                    {'type': 'float',
                                     'desc': 'podstawa liczby wykładniczej',
                                     'def' : '10.0'                                        
                                    },
                               'min': 
                                    {'type': 'float',
                                     'desc': 'wartość minimalna wykładnika',
                                     'def' : '0.0'
                                    },
                               'max':
                                    {'type': 'float',
                                     'desc': 'wartość maksymalna wykładnika',
                                     'def' : '10000.0'
                                    },
                               'step': 
                                    {'type': 'float',
                                     'desc': 'skok wykładnika liczby',
                                     'def' : '0.1'
                                    },
                               'description': 
                                    {'type': 'string',
                                     'desc': 'opis/etykieta wyświetlany przy suwaku',
                                     'def' : ''
                                    },
                               'description_tooltip':
                                    {'type': 'string',
                                     'desc': 'opis wyświetlany przy najechaniu kursorem na suwak',
                                     'def' : ''
                                    },
                               'disabled': 
                                    {'type': 'bool',
                                     'desc': 'czy suwak jest wyłączony/nieaktywny',
                                     'def' : 'False'
                                    },
                               'continuous_update': 
                                    {'type': 'bool',
                                     'desc': 'czy wartość zmienia się podczas przeciągania myszą lub dopiero po puszczeniu',
                                     'def' : 'True'
                                    },
                               'orientation': 
                                    {'type': 'horizontal|vertical',
                                     'desc': 'orientracja pozioma lub pionowa',
                                     'def' : 'horizontal'
                                    },
                               'readout': 
                                    {'type': 'bool',
                                     'desc': 'czy wyświetlać aktualną wartość w postaci liczbowej',
                                     'def' : 'True'
                                    },
                               'readout_format': 
                                    {'type': 'string',
                                     'desc': 'string formatujący wartość liczbową',
                                     'def' : '.2f'
                                    }
                              }
                    },  
              'Zakres liczb całkowitych': '',
              'Zakres liczb rzeczywistych': '',
              'Progress (integer)': '',
              'Progress (float)': '',
              'Bounded text (integer)': '',
              'Bounded text (float)': '',
              'Text (integer)': '',
              'Text (float)': '',
              'Toggle button': '',
              'Checkbox': '',
              'Valid (read-only)': '',
              'Dropdown': '',
              'Radio buttons': '',
              'Select': '',
              'Selection slider': '',
              'Selection range slider': '',
              'Toggle buttons': '',
              'Select multiple': '',
              'Text': '',
              'Text area': '',
              'Label': '',
              'HTML': '',
              'HTML Math': '',
              'Image': '',
              'Button': '',
              'Output': '',
              'Play animation': '',
              'Date picker': '',
              'Color picker': '',
              'File upload': '',
              }

widget_select = widgets.Dropdown(options=widget_repo.items(), description= 'Widget')
widget_desc = widgets.Label(value = widget_select.value['desc'])

def on_widget_select_change(change):
    global widget_desc, widget_repo
    widget_desc.value = change['new']['desc']
    
widget_select.observe(on_widget_select_change, names='value')

# %%
display(widget_select, widget_desc)
# Out:
# Dropdown(description='Widget', options=(('Suwak liczb całkowitych', {'desc': 'Suwak do określania wartości cał…
# Label(value='Suwak do określania wartości całkowitej z wybranego zakresu')
