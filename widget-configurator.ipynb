# %%
import ipywidgets as widgets
from IPython.display import display

# %%
widget_repo = {'Suwak liczb całkowitych': 
                    {'desc': 'Suwak do określania liczby całkowitej z wybranego zakresu',
                     'cons': 'IntSlider',
                     'cat' : 'numeric',
                     'props': {'value': 
                                    {'type': 'int',
                                     'desc': 'wybrana wartość suwaka',
                                     'def' : '0'
                                    },
                               'min': 
                                    {'type': 'int',
                                     'desc': 'wartość minimalna suwaka',
                                     'def' : '0'
                                    },
                               'max':
                                    {'type': 'int',
                                     'desc': 'wartość maksymalna suwaka',
                                     'def' : '100'
                                    },
                               'step': 
                                    {'type': 'int',
                                     'desc': 'skok suwaka',
                                     'def' : '1'
                                    },
                               'description': 
                                    {'type': 'string',
                                     'desc': 'opis/etykieta wyświetlany przy suwaku',
                                     'def' : ''
                                    },
                               'description_tooltip':
                                    {'type': 'string',
                                     'desc': 'opis wyświetlany przy najechaniu kursorem na suwak',
                                     'def' : ''
                                    },
                               'disabled': 
                                    {'type': 'bool',
                                     'desc': 'czy suwak jest wyłączony/nieaktywny',
                                     'def' : 0
                                    },
                               'continuous_update': 
                                    {'type': 'bool',
                                     'desc': 'czy wartość zmienia się podczas przeciągania myszą lub dopiero po puszczeniu',
                                     'def' : 1
                                    },
                               'orientation': 
                                    {'type': 'horizontal|vertical',
                                     'desc': 'orientracja pozioma lub pionowa',
                                     'def' : 'horizontal'
                                    },
                               'readout': 
                                    {'type': 'bool',
                                     'desc': 'czy wyświetlać aktualną wartość w postaci liczbowej',
                                     'def' : 1
                                    },
                               'readout_format': 
                                    {'type': 'string',
                                     'desc': 'string formatujący wartość liczbową',
                                     'def' : 'd'
                                    }
                              }
                    }, 
              'Suwak liczb rzeczywistych':
                    {'desc': 'Suwak do określania liczby rzeczywistej z wybranego zakresu',
                     'cons': 'IntSlider',
                     'cat' : 'numeric',
                     'props': {'value': 
                                    {'type': 'float',
                                     'desc': 'wybrana wartość suwaka',
                                     'def' : '0.0'
                                    },
                               'min': 
                                    {'type': 'float',
                                     'desc': 'wartość minimalna suwaka',
                                     'def' : '0.0'
                                    },
                               'max':
                                    {'type': 'float',
                                     'desc': 'wartość maksymalna suwaka',
                                     'def' : '100.0'
                                    },
                               'step': 
                                    {'type': 'float',
                                     'desc': 'skok suwaka',
                                     'def' : '0.1'
                                    },
                               'description': 
                                    {'type': 'string',
                                     'desc': 'opis/etykieta wyświetlany przy suwaku',
                                     'def' : ''
                                    },
                               'description_tooltip':
                                    {'type': 'string',
                                     'desc': 'opis wyświetlany przy najechaniu kursorem na suwak',
                                     'def' : ''
                                    },
                               'disabled': 
                                    {'type': 'bool',
                                     'desc': 'czy suwak jest wyłączony/nieaktywny',
                                     'def' : 0
                                    },
                               'continuous_update': 
                                    {'type': 'bool',
                                     'desc': 'czy wartość zmienia się podczas przeciągania myszą lub dopiero po puszczeniu',
                                     'def' : 1
                                    },
                               'orientation': 
                                    {'type': 'horizontal|vertical',
                                     'desc': 'orientracja pozioma lub pionowa',
                                     'def' : 'horizontal'
                                    },
                               'readout': 
                                    {'type': 'bool',
                                     'desc': 'czy wyświetlać aktualną wartość w postaci liczbowej',
                                     'def' : 1
                                    },
                               'readout_format': 
                                    {'type': 'string',
                                     'desc': 'string formatujący wartość liczbową',
                                     'def' : '.2f'
                                    }
                              }
                    },  
              'Suwak wykładniczy rzeczywistych':
                    {'desc': 'Suwak do określania liczby rzeczywistej w postaci wykładniczej z wybranego zakresu',
                     'cons': 'IntSlider',
                     'cat' : 'numeric',
                     'props': {'value': 
                                    {'type': 'float',
                                     'desc': 'wybrana wartość suwaka',
                                     'def' : '0.0'
                                    },
                               'base':
                                    {'type': 'float',
                                     'desc': 'podstawa liczby wykładniczej',
                                     'def' : '10.0'                                        
                                    },
                               'min': 
                                    {'type': 'float',
                                     'desc': 'wartość minimalna wykładnika',
                                     'def' : '0.0'
                                    },
                               'max':
                                    {'type': 'float',
                                     'desc': 'wartość maksymalna wykładnika',
                                     'def' : '10000.0'
                                    },
                               'step': 
                                    {'type': 'float',
                                     'desc': 'skok wykładnika liczby',
                                     'def' : '0.1'
                                    },
                               'description': 
                                    {'type': 'string',
                                     'desc': 'opis/etykieta wyświetlany przy suwaku',
                                     'def' : ''
                                    },
                               'description_tooltip':
                                    {'type': 'string',
                                     'desc': 'opis wyświetlany przy najechaniu kursorem na suwak',
                                     'def' : ''
                                    },
                               'disabled': 
                                    {'type': 'bool',
                                     'desc': 'czy suwak jest wyłączony/nieaktywny',
                                     'def' : 0
                                    },
                               'continuous_update': 
                                    {'type': 'bool',
                                     'desc': 'czy wartość zmienia się podczas przeciągania myszą lub dopiero po puszczeniu',
                                     'def' : 1
                                    },
                               'orientation': 
                                    {'type': 'horizontal|vertical',
                                     'desc': 'orientracja pozioma lub pionowa',
                                     'def' : 'horizontal'
                                    },
                               'readout': 
                                    {'type': 'bool',
                                     'desc': 'czy wyświetlać aktualną wartość w postaci liczbowej',
                                     'def' : 1
                                    },
                               'readout_format': 
                                    {'type': 'string',
                                     'desc': 'string formatujący wartość liczbową',
                                     'def' : '.2f'
                                    }
                              }
                    },  
              'Zakres liczb całkowitych': '',
              'Zakres liczb rzeczywistych': '',
              'Progress (integer)': '',
              'Progress (float)': '',
              'Bounded text (integer)': '',
              'Bounded text (float)': '',
              'Text (integer)': '',
              'Text (float)': '',
              'Toggle button': '',
              'Checkbox': '',
              'Valid (read-only)': '',
              'Dropdown': '',
              'Radio buttons': '',
              'Select': '',
              'Selection slider': '',
              'Selection range slider': '',
              'Toggle buttons': '',
              'Select multiple': '',
              'Text': '',
              'Text area': '',
              'Label': '',
              'HTML': '',
              'HTML Math': '',
              'Image': '',
              'Button': '',
              'Output': '',
              'Play animation': '',
              'Date picker': '',
              'Color picker': '',
              'File upload': '',
              }

widget_select = widgets.Dropdown(options=widget_repo.items(), description= 'Widget')
widget_desc = widgets.Label(value = widget_select.value['desc'])
s = '<TABLE WIDTH=1000px><TH>Właściwość</TH><TH>Typ danych</TH><TH>Wartość domyślna</TH><TH>Opis</TH>'
for prop, var in widget_select.value['props'].items():
    s = s + '<TR><TD><B>{}</B></TD><TD>{}</TD><TD>{}</TD><TD><I>{}</I></TD></TR>'.format(prop, var['type'], var['def'], var['desc'])
#widget_props = widgets.HTML(value= s)
widget_props = widgets.VBox()

def on_widget_select_change(change):
    global widget_desc, widget_repo, widget_props
    props = {}
    widget_desc.value = change['new']['desc']
    s = '<TABLE WIDTH=1000px><TH>Właściwość</TH><TH>Typ danych</TH><TH>Wartość domyślna</TH><TH>Opis</TH>'
    for prop, var in widget_select.value['props'].items():
        if var['type'] == 'int':
            c = widgets.IntText()
            c.value = var['def']
        elif var['type'] == 'float':
            c = widgets.FloatText()
            c.value = var['def']
        elif var['type'] == 'bool':
            c = widgets.Checkbox()
            if var['def'] == 1:
                c.value = True
            else:
                c.value = False
        elif var['type'] == 'string':
            c = widgets.Text()
            c.value = var['def']
        elif '|' in var['type']:
            c = widgets.Dropdown(options=var['type'].split('|'))
            c.value = var['def']
        c.description = prop
        c.description_tooltip = var['desc']
        props[prop] = c
        #s = s + '<TR><TD><B>{}</B></TD><TD>{}</TD><TD>{}</TD><TD><I>{}</I></TD></TR>'.format(prop, var['type'], var['def'], var['desc'])
    widget_props.children = tuple(props.values())
    
widget_select.observe(on_widget_select_change, names='value')

# %%
display(widget_select, widget_desc, widget_props)
# Out:
# Dropdown(description='Widget', options=(('Suwak liczb całkowitych', {'desc': 'Suwak do określania liczby całko…
# Label(value='Suwak do określania liczby całkowitej z wybranego zakresu')
# VBox()

# %%
w = widgets.Label("jakiś tekst")
d = dict()
d['label1'] = w

# %%
props.values()
# Out:
# dict_values([FloatText(value=0.0, description='value', description_tooltip='wybrana wartość suwaka'), FloatText(value=0.0, description='min', description_tooltip='wartość minimalna suwaka'), FloatText(value=100.0, description='max', description_tooltip='wartość maksymalna suwaka'), FloatText(value=0.1, description='step', description_tooltip='skok suwaka'), Text(value='', description='description', description_tooltip='opis/etykieta wyświetlany przy suwaku'), Text(value='', description='description_tooltip', description_tooltip='opis wyświetlany przy najechaniu kursorem na suwak'), Checkbox(value=False, description='disabled', description_tooltip='czy suwak jest wyłączony/nieaktywny'), Checkbox(value=True, description='continuous_update', description_tooltip='czy wartość zmienia się podczas przeciągania myszą lub dopiero po puszczeniu'), Dropdown(description='orientation', description_tooltip='orientracja pozioma lub pionowa', options=('horizontal', 'vertical'), value='horizontal'), Checkbox(value=True, description='readout', description_tooltip='czy wyświetlać aktualną wartość w postaci liczbowej'), Text(value='', description='readout_format', description_tooltip='string formatujący wartość liczbową')])

# %%
ww =widgets.BoundedFloatText(
value=7.5,
min=0,
max=10.0,
step=0.1,
description='Text:',
disabled=False
)
ww
# Out:
# BoundedFloatText(value=7.5, description='Text:', max=10.0, step=0.1)
